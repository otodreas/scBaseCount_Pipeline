# %%
import pandas as pd

# %%
df = pd.read_csv("output/datasets_with_study_description.csv")

# %%
df.sample(n=1)
# Out:
#    srx_accession                                  study_description
# 66   SRX22996378  9 patients with LUAD that went through scRNA s...

# %%
df["study_description"].nunique()
# Out:
# 121
