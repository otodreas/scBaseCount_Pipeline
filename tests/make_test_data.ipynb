# %%
from pathlib import Path
import pandas as pd

df = pd.read_csv(Path().resolve().parent / "output" / "metadata" / "datasets.csv")
df.head()
# Out:
#   srx_accession                                          file_path  obs_count
# 0   ERX11662371  gs://arc-institute-virtual-cell-atlas/scbaseco...       2840
# 1   SRX19233503  gs://arc-institute-virtual-cell-atlas/scbaseco...       4404
# 2   ERX11662373  gs://arc-institute-virtual-cell-atlas/scbaseco...       3124
# 3   ERX11662385  gs://arc-institute-virtual-cell-atlas/scbaseco...       6929
# 4   ERX11662357  gs://arc-institute-virtual-cell-atlas/scbaseco...      16332

# %%
TEST_NAME = "sample10"

df = df.sample(n=10, random_state=0)

df.to_csv(Path().resolve() / f"datasets_{TEST_NAME}.csv", index=False)
