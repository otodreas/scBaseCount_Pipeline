# %%
from pathlib import Path

import pandas as pd

df = pd.read_csv(Path().resolve().parent / "output" / "metadata" / "datasets.csv")
df.head()

# %%
TEST_NAME = "sample2"

df = df.sample(n=2, random_state=0)

df.to_csv(Path().resolve() / f"datasets_{TEST_NAME}.csv", index=False)

# %%
df = df[df["srx_accession"].isin(["SRX12366723", "SRX13198730", "SRX17412841"])]

df.to_csv(Path().resolve() / f"datasets_{'state_matrix'}.csv", index=False)
